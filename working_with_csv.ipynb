# %%
import pandas as pd

# %% [markdown]
# SEP Parameter

# %%
pd.read_csv('data/movie_titles_metadata.tsv', sep='\t', names=['sno', 'name', 'year', 'rating', 'votes', 'genre'])
# Out:
#       sno                        name  year  rating     votes  \
# 0      m0  10 things i hate about you  1999     6.9   62847.0
# 1      m1  1492: conquest of paradise  1992     6.2   10421.0
# 2      m2                  15 minutes  2001     6.1   25854.0
# 3      m3       2001: a space odyssey  1968     8.4  163227.0
# 4      m4                     48 hrs.  1982     6.9   22289.0
# ..    ...                         ...   ...     ...       ...
# 612  m612                    watchmen  2009     7.8  135229.0
# 613  m613                         xxx  2002     5.6   53505.0
# 614  m614                       x-men  2000     7.4  122149.0
# 615  m615          young frankenstein  1974     8.0   57618.0
# 616  m616                   zulu dawn  1979     6.4    1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# INDEX COL

# %%
pd.read_csv('data/aug_train.csv', index_col='enrollee_id').head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %% [markdown]
# Use Columns

# %%
pd.read_csv('data/aug_train.csv', usecols=['city', 'gender', 'relevent_experience'])
# Out:
#            city gender      relevent_experience
# 0      city_103   Male  Has relevent experience
# 1       city_40   Male   No relevent experience
# 2       city_21    NaN   No relevent experience
# 3      city_115    NaN   No relevent experience
# 4      city_162   Male  Has relevent experience
# ...         ...    ...                      ...
# 19153  city_173   Male   No relevent experience
# 19154  city_103   Male  Has relevent experience
# 19155  city_103   Male  Has relevent experience
# 19156   city_65   Male  Has relevent experience
# 19157   city_67    NaN   No relevent experience
#
# [19158 rows x 3 columns]

# %% [markdown]
# Squeeze Parameter(deprecated) instead use squeeze func

# %%
pd.read_csv('data/aug_train.csv', usecols=['gender']).squeeze()
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: str

# %% [markdown]
# ENCODING

# %%
pd.read_csv('data/zomato.csv', encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# error_bad_lines replaced with on_bad_lines

# %% [markdown]
# dtypes

# %%
pd.read_csv('data/aug_train.csv', dtype={'target':  int})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# Make strings to dates: parse_dates

# %% [markdown]
# CONVERTORS and Na values

# %%
def rename(obj):
    if obj == "no_enrollment":
        return "berojgaar"
    else:
        return obj

pd.read_csv('data/aug_train.csv', converters = {'enrolled_university': rename}, na_values=['No relevent experience', ])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience           berojgaar        Graduate
# 1                          NaN           berojgaar        Graduate
# ...

# %%
dfs = pd.read_csv('data/aug_train.csv', chunksize = 5000)

for chunks in dfs:
    print(chunks.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 dfs = pd.read_csv('data/aug_train.csv', chunksize = 5000)
#       3 for chunks in dfs:
# ----> 4     print(chunk.shape)
#
# NameError: name 'chunk' is not defined
